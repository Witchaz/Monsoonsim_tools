# %%
import matplotlib as mpl
import pandas as pd
import numpy as np

import random

# %%
df = pd.read_csv("MARKETING-Survey.csv")
df.columns = df.columns.str.strip()
df
# Out:
#     &nbsp         Person  Age Product Preference Media Preference
# 0       1      Kong Jose   28        Apple Juice          Media C
# 1       2  Yeon Jonathan   71       Orange Juice          Media A
# 2       3       Cruz Aoi   78        Apple Juice          Media A
# 3       4    Kelly Green   65       Orange Juice          Media A
# 4       5   Young Amanda   84       Orange Juice          Media B
# ..    ...            ...  ...                ...              ...
# 95     96    Chris Louis   78        Melon Juice          Media A
# 96     97     Ward Owens   16        Melon Juice          Media A
# 97     98  Bryan Jackson   83       Orange Juice          Media A
# 98     99       Ma Poula   49        Apple Juice          Media B
# 99    100     Zheng Dewi   17        Apple Juice          Media C
#
# [100 rows x 5 columns]

# %%
def condition(v):
    if v > 10:
        return "Hot"
    elif v > 5:
        return "normal"
    else:
        return "ignore"

def make_pretty(styler):
    styler.set_caption("Marketing survey")
    styler.background_gradient(axis=None, vmin=5, vmax=15, cmap="RdPu")
    return styler

# %%
df['Age Group'] = pd.cut(df['Age'], bins=[0, 30, 60, float('inf')], labels=['30 and below', '30-60', 'Above 60'])
media_counts_in_groups = df.groupby(['Age Group','Product Preference'])['Media Preference'].value_counts().unstack(fill_value=0)
media_counts_in_groups.style.pipe(make_pretty)
media_counts_in_groups.reset_index(inplace=True)
media_counts_in_groups
# Out:
# C:\Users\jengk\AppData\Local\Temp\ipykernel_7328\4243274095.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   media_counts_in_groups = df.groupby(['Age Group','Product Preference'])['Media Preference'].value_counts().unstack(fill_value=0)
